# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from '/Users/victorkosgei/opt/anaconda3/lib/python3.9/site-packages/pandas/__init__.py'>

# %%
data = pd.read_csv("renewable-energy-stock-account-2007-2020-csv.csv")

# %%
print(data.head(5))
# Out:
#    year resource        variable           units   magnitude  \
# 0  2007   Biogas   Closing stock         Dollars   Thousands
# 1  2007   Biogas      Generation  Gigawatt hours      Actual
# 2  2007   Biogas  Gigawatt hours          Number  Proportion
# 3  2007   Biogas   Opening stock         Dollars   Thousands
# 4  2007   Biogas   Other changes         Dollars   Thousands
#
#                    source  data_value flag
# 0  Environmental Accounts    86656.00    R
# 1                    MBIE      224.00    F
# 2                    MBIE        0.01    F
# 3  Environmental Accounts         NaN    F
# 4  Environmental Accounts         NaN    F

# %%
print(data.columns)
# Out:
# Index(['year', 'resource', 'variable', 'units', 'magnitude', 'source',
#        'data_value', 'flag'],
#       dtype='object')

# %%
print(data.resource)
# Out:
# 0      Biogas
# 1      Biogas
# 2      Biogas
# 3      Biogas
# 4      Biogas
#         ...
# 694      Wood
# 695      Wood
# 696      Wood
# 697      Wood
# 698      Wood
# Name: resource, Length: 699, dtype: object

# %%
for index,row in data.iterrows():
    print(row.resource)
# Out:
# Biogas
# Biogas
# Biogas
# Biogas
# Biogas
# Biogas
# Coal
# Gas
# Geothermal
# Geothermal
# Geothermal
# Geothermal
# Geothermal
# Geothermal
# Hydro
# Hydro
# Hydro
# Hydro
# Hydro
# Hydro
# Oil
# Renewable
# Renewable
# Renewable
# Renewable
# Renewable
# Renewable
# Renewable
# Solar
# Solar
# Solar
# Solar
# Solar
# Solar
# Total generation
# Total generation
# Total generation
# Waste heat
# Wind
# Wind
# Wind
# Wind
# Wind
# Wind
# Wood
# Wood
# Wood
# Wood
# Wood
# Wood
# Biogas
# Biogas
# Biogas
# Biogas
# Biogas
# Biogas
# Coal
# Gas
# Geothermal
# Geothermal
# Geothermal
# Geothermal
# Geothermal
# Geothermal
# Hydro
# Hydro
# Hydro
# Hydro
# Hydro
# Hydro
# Oil
# Renewable
# Renewable
# Renewable
# Renewable
# Renewable
# Renewable
# Renewable
# Solar
# Solar
# Solar
# Solar
# Solar
# Solar
# Total generation
# Total generation
# Total generation
# Waste heat
# Wind
# Wind
# Wind
# Wind
# Wind
# Wind
# Wood
# Wood
# Wood
# Wood
# Wood
# Wood
# Biogas
# Biogas
# Biogas
# ...

# %%
data.loc[data.resource =="Hydro"]
# Out:
#      year resource        variable           units   magnitude  \
# 14   2007    Hydro   Closing stock         Dollars   Thousands
# 15   2007    Hydro      Generation  Gigawatt hours      Actual
# 16   2007    Hydro  Gigawatt hours          Number  Proportion
# 17   2007    Hydro   Opening stock         Dollars   Thousands
# 18   2007    Hydro   Other changes         Dollars   Thousands
# ..    ...      ...             ...             ...         ...
# 665  2020    Hydro      Generation  Gigawatt hours      Actual
# 666  2020    Hydro  Gigawatt hours          Number  Proportion
# 667  2020    Hydro   Opening stock         Dollars   Thousands
# 668  2020    Hydro   Other changes         Dollars   Thousands
# 669  2020    Hydro   Resource rent         Dollars   Thousands
#
#                      source  data_value flag
# 14   Environmental Accounts  9380001.00    R
# 15                     MBIE    24249.00    F
# 16                     MBIE        0.58    F
# ...

# %%
data.describe()
# Out:
#               year    data_value
# count   699.000000  6.850000e+02
# mean   2013.490701  1.099322e+06
# std       4.029385  3.114252e+06
# min    2007.000000 -3.111777e+06
# 25%    2010.000000  4.700000e+01
# 50%    2013.000000  8.316000e+03
# 75%    2017.000000  2.184000e+05
# max    2020.000000  1.714458e+07

# %%
data.sort_values('resource')
# Out:
#      year resource        variable           units   magnitude  \
# 0    2007   Biogas   Closing stock         Dollars   Thousands
# 105  2009   Biogas   Resource rent         Dollars   Thousands
# 104  2009   Biogas   Other changes         Dollars   Thousands
# 103  2009   Biogas   Opening stock         Dollars   Thousands
# 102  2009   Biogas  Gigawatt hours          Number  Proportion
# ..    ...      ...             ...             ...         ...
# 445  2015     Wood      Generation  Gigawatt hours      Actual
# 446  2015     Wood  Gigawatt hours          Number  Proportion
# 447  2015     Wood   Opening stock         Dollars   Thousands
# 299  2012     Wood   Resource rent         Dollars   Thousands
# 698  2020     Wood   Resource rent         Dollars   Thousands
#
#                      source  data_value flag
# 0    Environmental Accounts    86656.00    R
# 105  Environmental Accounts     5136.00    F
# 104  Environmental Accounts     1692.00    R
# ...

# %%
data.groupby('resource').mean()
# Out:
#                          year    data_value
# resource
# Biogas            2013.500000  3.151812e+04
# Coal              2013.500000  2.422786e+03
# Gas               2013.500000  7.630143e+03
# Geothermal        2013.500000  8.431096e+05
# Hydro             2013.500000  3.319291e+06
# Oil               2013.500000  1.257143e+01
# Renewable         2013.500000  3.842671e+06
# Solar             2013.500000  4.851793e+03
# Total generation  2013.341463  3.683222e+05
# Waste heat        2013.500000  4.985714e+01
# Wind              2013.500000  2.538718e+05
# Wood              2013.500000  4.609427e+04
